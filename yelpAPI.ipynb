# %%
# Dependencies and Setup (dont need most of these for now)
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import yelp_key

# I used my city just as example location
HEADERS = {"Authorization": "bearer %s" %yelp_key}
PARAMS = {"term": "restaurant", 
          "location": "Kansas City", 
          "limit": 50}
url = "https://api.yelp.com/v3/businesses/search"
response = requests.get(url, params=PARAMS, headers=header).json()
response
# Out:
# {'businesses': [{'id': 'cC6V4pEnT_-4C61OZZOWug',
#    'alias': 'mason-jar-kansas-city-2',
#    'name': 'Mason Jar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O0gCGR7y9BkGm8ecZp0V2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mason-jar-kansas-city-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 257,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.1153106090531,
#     'longitude': -94.750259465434},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '941 N 74th Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '66112',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['941 N 74th Dr', 'Kansas City, KS 66112']},
#    'phone': '+19132428165',
#    'display_phone': '(913) 242-8165',
#    'distance': 2830.0972584342126},
#   {'id': '1Wv4PZNFtZJKUIVKgi7Jkw',
#    'alias': 'brown-sugar-chicken-and-donuts-kansas-city',
#    'name': 'Brown Sugar Chicken & Donuts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0kzlDD1fupDnwAXEubsqng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brown-sugar-chicken-and-donuts-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 41,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.1171105056106,
#     'longitude': -94.6714334562421},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '3708 State Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '66102',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['3708 State Ave', 'Kansas City, KS 66102']},
#    'phone': '+19132968870',
#    'display_phone': '(913) 296-8870',
#    'distance': 5710.204430238701},
#   {'id': 'Gu9XIXNK3KpZu5DMF0SlJw',
#    'alias': 'don-antonios-carnicería-y-taqueria-kansas-city',
#    'name': "Don Antonio's Carnicería Y Taqueria",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/61UstIXsH-pNvcCP4YaNDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-antonios-carnicer%C3%ADa-y-taqueria-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 98,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.1169179, 'longitude': -94.7528958},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7510 State Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66112',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['7510 State Ave', 'Kansas City, KS 66112']},
#    'phone': '+19132998898',
#    'display_phone': '(913) 299-8898',
#    'distance': 3109.3673929824026},
#   {'id': '2WoigKND2DiwaO1BvcGonw',
#    'alias': 'jones-bar-b-q-kansas-city',
#    'name': 'Jones Bar-B-Q',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wZiDSNWtqKzM03t9yhleCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jones-bar-b-q-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 111,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.089422, 'longitude': -94.732791},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6706 Kaw Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66111',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['6706 Kaw Dr', 'Kansas City, KS 66111']},
#    'phone': '+19137885005',
#    'display_phone': '(913) 788-5005',
#    'distance': 608.8824906654684},
#   {'id': 'VZ7ZjroMwJMvZGxfHghuGA',
#    'alias': 'the-brgr-spot-kansas-city',
#    'name': 'The Brgr spot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y9NzZnkhAPdzfnQQ3QDenQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brgr-spot-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 13,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.1281824851904,
#     'longitude': -94.7298755753937},
#    'transactions': ['delivery'],
#    'location': {'address1': '6519 Parallel Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66102',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['6519 Parallel Pkwy', 'Kansas City, KS 66102']},
#    'phone': '+19139127038',
#    'display_phone': '(913) 912-7038',
#    'distance': 3722.546960865419},
#   {'id': 'snF9XeUAtv-Vp9coGa2rDQ',
#    'alias': 'slaps-bbq-kansas-city-2',
#    'name': "Slap's BBQ",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/59nexERs82f8hHEDq1kZqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slaps-bbq-kansas-city-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 819,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.10248, 'longitude': -94.62443},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '553 Central Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66101',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['553 Central Ave', 'Kansas City, KS 66101']},
#    'phone': '+19132133736',
#    'display_phone': '(913) 213-3736',
#    'distance': 9236.518185072873},
#   {'id': 'QhzJXO6E_oLAx1Wz1Z_T2g',
#    'alias': 'joes-kansas-city-bar-b-que-kansas-city-3',
#    'name': "Joe's Kansas City Bar-B-Que",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gminzak55H9KOyTAJU7LXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-kansas-city-bar-b-que-kansas-city-3?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 3785,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.044461224899, 'longitude': -94.620753657734},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3002 W 47th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66103',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['3002 W 47th Ave', 'Kansas City, KS 66103']},
#    'phone': '+19137223366',
#    'display_phone': '(913) 722-3366',
#    'distance': 11035.806162114568},
#   {'id': 'R_nUTZ656X6ikQ0ikMA9hA',
#    'alias': 'noodle-bar-kansas-city-3',
#    'name': 'Noodle Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/py_yg44FKQGoiD-BxeQyOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noodle-bar-kansas-city-3?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 111,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.12985, 'longitude': -94.83347},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '10940 F Parallel Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66109',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['10940 F Parallel Pkwy', 'Kansas City, KS 66109']},
#    'phone': '+19133280783',
#    'display_phone': '(913) 328-0783',
#    'distance': 9721.037400029834},
#   {'id': 'Bh60zqgTAgJ0ePOL50tg1A',
#    'alias': 'wandering-vine-at-the-castle-shawnee',
#    'name': 'Wandering Vine at the Castle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HE1w-ll_gq1M8vbZBC4ixg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wandering-vine-at-the-castle-shawnee?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 3,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.0216, 'longitude': -94.72946},
#    'transactions': [],
#    'location': {'address1': '12401 Johnson Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Shawnee',
#     'zip_code': '66216',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['12401 Johnson Dr', 'Shawnee, KS 66216']},
#    'phone': '+19133791300',
#    'display_phone': '(913) 379-1300',
#    'distance': 8137.085880257784},
#   {'id': 'EHjOoKjuLdP11d7E91_83A',
#    'alias': 'italian-delight-kansas-city',
#    'name': 'Italian Delight',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tvYNYsp73cFwDz3Ckky9Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italian-delight-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 95,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.115747, 'longitude': -94.7691062766459},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '8145 State Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66112',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['8145 State Ave', 'Kansas City, KS 66112']},
#    'phone': '+19132874323',
#    'display_phone': '(913) 287-4323',
#    'distance': 4035.722222029123},
#   {'id': 'sSDlny5Ao9Ge8PgeWi_3DA',
#    'alias': 'yard-house-kansas-city-6',
#    'name': 'Yard House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/whe77N6usEFVE41awFbJ0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yard-house-kansas-city-6?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 427,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.1267050714673,
#     'longitude': -94.8281054130859},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1863 Village West Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66111',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['1863 Village West Pkwy', 'Kansas City, KS 66111']},
#    'phone': '+19137884500',
#    'display_phone': '(913) 788-4500',
#    'distance': 9102.984882863864},
#   {'id': 'p0tO2iT-IPDTbtejiOBEsA',
#    'alias': 'naree-kitchen-kansas-city',
#    'name': 'Naree Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/spsQeTthkZx203iVyR8xbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naree-kitchen-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 78,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.115719594548,
#     'longitude': -94.7645926102996},
#    'transactions': ['delivery'],
#    'location': {'address1': '7933 State Ave',
#     'address2': 'Ste 105',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '66112',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['7933 State Ave', 'Ste 105', 'Kansas City, KS 66112']},
#    'phone': '+19137661202',
#    'display_phone': '(913) 766-1202',
#    'distance': 3723.2385863226746},
#   {'id': 'kuOtytwBW0LQLcIyRyklbw',
#    'alias': 'krab-kingz-kck-kansas-city-2',
#    'name': 'Krab Kingz Seafood KCK',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3n-9gBZ17Vrdrg5_iHh5hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krab-kingz-kck-kansas-city-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 6,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.117732, 'longitude': -94.759014},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7704 State Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'kansas city',
#     'zip_code': '66112',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['7704 State Ave', 'kansas city, KS 66112']},
#    'phone': '+19139121714',
#    'display_phone': '(913) 912-1714',
#    'distance': 3520.8561455804643},
#   {'id': 'XH_c2gzMz1tzG2Jmlrc3dg',
#    'alias': 'la-fuente-mexican-street-food-kansas-city',
#    'name': 'La Fuente Mexican Street Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wjo02ySgeZ3abH2nv9Jmhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-fuente-mexican-street-food-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 10,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.126186, 'longitude': -94.833707},
#    'transactions': [],
#    'location': {'address1': '10932 Stadium Dr',
#     'address2': '',
#     'address3': 'Legends Outlet Mall',
#     'city': 'Kansas City',
#     'zip_code': '66111',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['10932 Stadium Dr',
#      'Legends Outlet Mall',
#      'Kansas City, KS 66111']},
#    'phone': '+19137308620',
#    'display_phone': '(913) 730-8620',
#    'distance': 9528.410487556588},
#   {'id': 'Fl3b8UIeGfaT9Sd65bqO_g',
#    'alias': 'christys-tasty-queen-kansas-city',
#    'name': "Christy's Tasty Queen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d3oIQttWK1Ua7gMuyqRoZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/christys-tasty-queen-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 46,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.0747975, 'longitude': -94.704911},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1405 S 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66106',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['1405 S 55th St', 'Kansas City, KS 66106']},
#    'phone': '+19132872800',
#    'display_phone': '(913) 287-2800',
#    'distance': 3157.6977755489966},
#   {'id': 'lhDOwGqCUo0nrjjK5RtIxA',
#    'alias': 'jarocho-kansas-city',
#    'name': 'Jarocho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x1p8qrQm1nN_29rc4YlyCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jarocho-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 225,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.08723, 'longitude': -94.62693},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '719 Kansas Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66105',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['719 Kansas Ave', 'Kansas City, KS 66105']},
#    'phone': '+19132817757',
#    'display_phone': '(913) 281-7757',
#    'distance': 9019.340134588258},
#   {'id': 'HV0APluxN8ZsV7SZKQ1Ihg',
#    'alias': 'ggs-barbacoa-cafe-kansas-city-15',
#    'name': 'Ggs Barbacoa Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O4PumGLhHlvexsnXNNLAow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ggs-barbacoa-cafe-kansas-city-15?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 45,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.098703, 'longitude': -94.626408},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '210 S 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66101',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['210 S 7th St', 'Kansas City, KS 66101']},
#    'phone': '+19135628264',
#    'display_phone': '(913) 562-8264',
#    'distance': 9035.197967937158},
#   {'id': 'D3YNNWg0nP4iwuesJ5tAaA',
#    'alias': 'seafood-island-shawnee-2',
#    'name': 'Seafood Island',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/huJpTMwBNpB53K--S8JYdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seafood-island-shawnee-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 27,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.99351, 'longitude': -94.71102},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '10810 W 75th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Shawnee',
#     'zip_code': '66214',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['10810 W 75th St', 'Shawnee, KS 66214']},
#    'phone': '+19132709999',
#    'display_phone': '(913) 270-9999',
#    'distance': 11380.286523149223},
#   {'id': 'ykY_YI0JAP8th5D_8dteeQ',
#    'alias': 'california-taco-shop-kansas-city',
#    'name': 'California Taco Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b33pgM_N8oFdDNB8tPuobw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/california-taco-shop-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 65,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.0875301, 'longitude': -94.6433817},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1268 Kansas Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66106',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['1268 Kansas Ave', 'Kansas City, KS 66106']},
#    'phone': '+19132817773',
#    'display_phone': '(913) 281-7773',
#    'distance': 7602.767886941281},
#   {'id': 'cIKoYuaiOAdDM3WjucN_Fg',
#    'alias': 'guss-world-famous-fried-chicken-kansas-city-5',
#    'name': "Gus's World Famous Fried Chicken",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/laWdEhWq-iswclzx9q0kCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guss-world-famous-fried-chicken-kansas-city-5?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 433,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.0444566499809,
#     'longitude': -94.6191491559148},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2816 W 47th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66103',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['2816 W 47th St', 'Kansas City, KS 66103']},
#    'phone': '+19132327091',
#    'display_phone': '(913) 232-7091',
#    'distance': 11155.727298626769},
#   {'id': '1xUh0RFSTs685FARg84aqA',
#    'alias': 'roscoes-barbeque-edwardsville',
#    'name': "Roscoe's Barbeque",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TY4SfdEhfd6oR-YFRSqt5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roscoes-barbeque-edwardsville?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 137,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.06063, 'longitude': -94.80553},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9711 Kaw Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Edwardsville',
#     'zip_code': '66111',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['9711 Kaw Dr', 'Edwardsville, KS 66111']},
#    'phone': '+19134224600',
#    'display_phone': '(913) 422-4600',
#    'distance': 7469.333306372094},
#   {'id': 'bnUhQplC61MmSsLCQgQDRQ',
#    'alias': 'el-camino-real-kansas-city-2',
#    'name': 'El Camino Real',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xXGUpIcDHFXj_CIDaMUZ7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-camino-real-kansas-city-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 246,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.114758, 'longitude': -94.626681},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '903 N 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66101',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['903 N 7th St', 'Kansas City, KS 66101']},
#    'phone': '+19133424333',
#    'display_phone': '(913) 342-4333',
#    'distance': 9272.057377239124},
#   {'id': 'MgKnCJp9uDeRLuWVjPfv8A',
#    'alias': 'grandstand-burgers-shawnee',
#    'name': 'Grandstand Burgers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AzbT8YEBtYQih9etkKjVaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grandstand-burgers-shawnee?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 191,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.0395673, 'longitude': -94.6862519},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4942 Merriam Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Shawnee',
#     'zip_code': '66203',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['4942 Merriam Dr', 'Shawnee, KS 66203']},
#    'phone': '+19133620111',
#    'display_phone': '(913) 362-0111',
#    'distance': 7247.10105730971},
#   {'id': 'Sl7F1u-DW0rANzx-15RufQ',
#    'alias': 'taqueria-arandas-kansas-city',
#    'name': 'Taqueria Arandas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0IiXzXijlY9HPmEYFkS7sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-arandas-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 57,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.11585, 'longitude': -94.76233},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '7901 State Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66112',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['7901 State Ave', 'Kansas City, KS 66112']},
#    'phone': '+19132998512',
#    'display_phone': '(913) 299-8512',
#    'distance': 3582.9130977724185},
#   {'id': 'AxeVd6m8GNy7mgq0-o_NAQ',
#    'alias': 'kc-gyro-guys-kansas-city-3',
#    'name': 'KC Gyro Guys',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zRq88Db7VYkXT2fCYSnlMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kc-gyro-guys-kansas-city-3?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 1,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.1427477, 'longitude': -94.7072883},
#    'transactions': ['delivery'],
#    'location': {'address1': '5531 Leavenworth Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66104',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['5531 Leavenworth Rd', 'Kansas City, KS 66104']},
#    'phone': '+19139675498',
#    'display_phone': '(913) 967-5498',
#    'distance': 5718.831578668784},
#   {'id': 'NzPPyCw-vfL9J1MpScXEGg',
#    'alias': 'sarah-s-on-the-hill-kansas-city',
#    'name': 'Sarah’s On The Hill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0xgNTj6yiKsZ01HUpcd2JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sarah-s-on-the-hill-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.11269167, 'longitude': -94.621555},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '612 N 5th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '66101',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['612 N 5th St', 'Kansas City, KS 66101']},
#    'phone': '+19136085801',
#    'display_phone': '(913) 608-5801',
#    'distance': 9642.252683972618},
#   {'id': 'MQLYNsifI7RwWB8xQGcm5Q',
#    'alias': 'granite-city-food-and-brewery-kansas-city-4',
#    'name': 'Granite City Food & Brewery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6-oeGKrk5EAMaGSyhOVOGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granite-city-food-and-brewery-kansas-city-4?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 240,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.12424, 'longitude': -94.82393},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1701 Village W Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66111',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['1701 Village W Pkwy', 'Kansas City, KS 66111']},
#    'phone': '+19133342255',
#    'display_phone': '(913) 334-2255',
#    'distance': 8675.186512841608},
#   {'id': 'IkXNmXMDlD2ShPuZ9UINHg',
#    'alias': 'sancho-streetside-shawnee',
#    'name': 'Sancho StreetSide',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dZ_2bjXibbMSWtUv2IFU3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sancho-streetside-shawnee?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 38,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.02272, 'longitude': -94.71479},
#    'transactions': ['delivery'],
#    'location': {'address1': '11101 Johnson Dr',
#     'address2': 'Ste 110',
#     'address3': '',
#     'city': 'Shawnee',
#     'zip_code': '66203',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['11101 Johnson Dr', 'Ste 110', 'Shawnee, KS 66203']},
#    'phone': '+19132516814',
#    'display_phone': '(913) 251-6814',
#    'distance': 8127.124503182437},
#   {'id': 'pbIVaIJ_jDPpvtJZ0zYM0w',
#    'alias': 'blind-box-bbq-kansas-city-2',
#    'name': 'Blind Box BBQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vEut50Hu4xhCv8AeRG9T8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blind-box-bbq-kansas-city-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 19,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.124963, 'longitude': -94.820243},
#    'transactions': ['delivery'],
#    'location': {'address1': '1601 Village West Pkwy',
#     'address2': '',
#     'address3': 'Nebraska Furniture Mart',
#     'city': 'Kansas City',
#     'zip_code': '66111',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['1601 Village West Pkwy',
#      'Nebraska Furniture Mart',
#      'Kansas City, KS 66111']},
#    'phone': '+19132684227',
#    'display_phone': '(913) 268-4227',
#    'distance': 8327.628226168907},
#   {'id': 'deg-08_bqFDT1G14vsiL-w',
#    'alias': 'el-toro-loco-kansas-city',
#    'name': 'El Toro Loco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qWcK-Pmz_OV4ZC2xBxFghQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-toro-loco-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 58,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.123218, 'longitude': -94.826831},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1706 Village W Pkwy',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '66111',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['1706 Village W Pkwy', 'Kansas City, KS 66111']},
#    'phone': '+19134003050',
#    'display_phone': '(913) 400-3050',
#    'distance': 8856.016677979114},
#   {'id': 'FMbHAZfDDs_-IWexe7DB-g',
#    'alias': 'bangkok-kitchen-kansas-city',
#    'name': 'Bangkok Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uQUgKUXEjnPysI1l-HTs1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-kitchen-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 55,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.055793, 'longitude': -94.612186},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '3934 Rainbow Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66103',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['3934 Rainbow Blvd', 'Kansas City, KS 66103']},
#    'phone': '+19137661710',
#    'display_phone': '(913) 766-1710',
#    'distance': 11131.13254106097},
#   {'id': 'SRK8RaXBx2e2vxw3tbTHHw',
#    'alias': 'tao-tao-kansas-city',
#    'name': 'Tao Tao',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zJ4PZNlo-vMC3Y6B4QykvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tao-tao-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 52,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.11582, 'longitude': -94.64335},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1300 Minnesota Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66102',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['1300 Minnesota Ave', 'Kansas City, KS 66102']},
#    'phone': '+19133421331',
#    'display_phone': '(913) 342-1331',
#    'distance': 7918.671767794776},
#   {'id': '0Ae3s7XKonrpGj-cdCIS8Q',
#    'alias': 'deep-roots-kansas-city',
#    'name': 'Deep Roots',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CQUPGu4BW50w7HwLoTMDlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/deep-roots-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 11,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.050442, 'longitude': -94.684537},
#    'transactions': ['delivery'],
#    'location': {'address1': '4601 Shawnee Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '66106',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['4601 Shawnee Dr', 'Kansas City, KS 66106']},
#    'phone': '+19136774502',
#    'display_phone': '(913) 677-4502',
#    'distance': 6349.4386194350745},
#   {'id': 'tAiZGOeSnjPCot21QZ0r4g',
#    'alias': 'the-mockingbird-lounge-kansas-city',
#    'name': 'The Mockingbird Lounge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RKRR8ufr53ah6djhRNtQqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mockingbird-lounge-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 86,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.1056909492256,
#     'longitude': -94.6224777156748},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '204 Orchard St',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '64101',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['204 Orchard St', 'Kansas City, KS 64101']},
#    'phone': '+19132838661',
#    'display_phone': '(913) 283-8661',
#    'distance': 9442.730100780715},
#   {'id': 'NYovoVUpIS622BMC-LCF4A',
#    'alias': 'el-pollo-rey-kansas-city',
#    'name': 'El Pollo Rey',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MYtDz2MjR4x_4xyBAsQ1_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-pollo-rey-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 224,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.0871925354004,
#     'longitude': -94.6318435668945},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '901 Kansas Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66105',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['901 Kansas Ave', 'Kansas City, KS 66105']},
#    'phone': '+19133714243',
#    'display_phone': '(913) 371-4243',
#    'distance': 8597.575379258878},
#   {'id': 'jRBuNAkvzh7P1Hpp_1Rwdg',
#    'alias': 'bay-boy-specialty-sandwiches-kansas-city',
#    'name': 'Bay Boy Specialty Sandwiches',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EYYf6r2_hJl-3FH6LbAByA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bay-boy-specialty-sandwiches-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 216,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.0423867, 'longitude': -94.6010129},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4706 Holly St',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '64112',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['4706 Holly St', 'Kansas City, MO 64112']},
#    'phone': '+18166733960',
#    'display_phone': '(816) 673-3960',
#    'distance': 12639.792218690185},
#   {'id': 'Xvz0VQJoP5XxIvkA3tnqYw',
#    'alias': 'elevate-bar-and-grill-kansas-city',
#    'name': 'Elevate Bar & Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-hspNOwbNGbnWiD1XZSyZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elevate-bar-and-grill-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 19,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.1164115417665,
#     'longitude': -94.7549597918987},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7543 State Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '66112',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['7543 State Ave', 'Kansas City, KS 66112']},
#    'phone': '+19137666610',
#    'display_phone': '(913) 766-6610',
#    'distance': 3177.7973052411453},
#   {'id': 'Ma7flAVSz1Yi2dPc8NUT0w',
#    'alias': 'the-campground-kansas-city',
#    'name': 'The Campground',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p9w5nnOupn89uOBKu-tBcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-campground-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 61,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.0948660646154, 'longitude': -94.604571},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1531 Genessee St',
#     'address2': '',
#     'address3': None,
#     'city': 'Kansas City',
#     'zip_code': '64102',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['1531 Genessee St', 'Kansas City, MO 64102']},
#    'phone': '+18166123434',
#    'display_phone': '(816) 612-3434',
#    'distance': 10909.596085267809},
#   {'id': 'yYHiPp-KfwrvO9eLGvPE1w',
#    'alias': 'go-chicken-go-kansas-city-4',
#    'name': 'Go-Chicken-Go',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1j0Cq7SxvDB8gopDNhRObw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/go-chicken-go-kansas-city-4?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 27,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.11596, 'longitude': -94.766},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '8017 State Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66112',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['8017 State Ave', 'Kansas City, KS 66112']},
#    'phone': '+19132998606',
#    'display_phone': '(913) 299-8606',
#    'distance': 3833.6303734703115},
#   {'id': '90XpUycuIEQ39DOLbRisyw',
#    'alias': 'blind-box-bbq-shawnee',
#    'name': 'Blind Box BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k0ieZmp0Q4q8idqvbHv0jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blind-box-bbq-shawnee?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 593,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.01589, 'longitude': -94.73944},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '13214 W 62nd Ter',
#     'address2': '',
#     'address3': '',
#     'city': 'Shawnee',
#     'zip_code': '66216',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['13214 W 62nd Ter', 'Shawnee, KS 66216']},
#    'phone': '+19132684227',
#    'display_phone': '(913) 268-4227',
#    'distance': 8790.914754001316},
#   {'id': 'gC9kyGJm7W2ViTI067ILfg',
#    'alias': 'the-corner-lalo-s-kitchen-mission',
#    'name': 'The Corner Lalo’s Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EK-XzwpoghZjLabqIRbtYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-corner-lalo-s-kitchen-mission?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 31,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.037657, 'longitude': -94.658843},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5038 Lamar Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Mission',
#     'zip_code': '66202',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['5038 Lamar Ave', 'Mission, KS 66202']},
#    'phone': '+19132327013',
#    'display_phone': '(913) 232-7013',
#    'distance': 8890.369563406719},
#   {'id': 'Ir-k5hfOaulaACG-C8uFKQ',
#    'alias': 'longboards-mission',
#    'name': 'Longboards',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E7dGM0mj9d_LbP3ybjMG_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/longboards-mission?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 201,
#    'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.022227659088,
#     'longitude': -94.6478187355125},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '5415 Johnson Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Mission',
#     'zip_code': '66205',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['5415 Johnson Dr', 'Mission, KS 66205']},
#    'phone': '+19132362523',
#    'display_phone': '(913) 236-2523',
#    'distance': 10795.194688932641},
#   {'id': 'h9srWTzN-DuetBis1Ikz0A',
#    'alias': 'bob-wasabi-kitchen-kansas-city',
#    'name': 'Bob Wasabi Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N0kezkat33puA2F2DyB_rA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bob-wasabi-kitchen-kansas-city?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 419,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.0575970134193,
#     'longitude': -94.6059091254527},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1726 W 39th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Kansas  City',
#     'zip_code': '64111',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['1726 W 39th St', 'Kansas  City, MO 64111']},
#    'phone': '+18167535797',
#    'display_phone': '(816) 753-5797',
#    'distance': 11558.975640279195},
#   {'id': 'ymQOQcIdTS1mVZ90OktfFg',
#    'alias': 'el-pulgarcito-salvadorean-restaurant-shawnee-2',
#    'name': 'El Pulgarcito Salvadorean Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Qla3H5xgmoGXhVuNnt0PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-pulgarcito-salvadorean-restaurant-shawnee-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 218,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'salvadoran', 'title': 'Salvadoran'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.02115, 'longitude': -94.69366},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5921 Merriam Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Shawnee',
#     'zip_code': '66203',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['5921 Merriam Dr', 'Shawnee, KS 66203']},
#    'phone': '+19133843887',
#    'display_phone': '(913) 384-3887',
#    'distance': 8779.504484007437},
#   {'id': 'OASrrWIhulQEYe9pp3LkWQ',
#    'alias': 'rice-bowl-kansas-city-2',
#    'name': 'Rice Bowl',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MlPXEAZiF2J9p5rmUxEWLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rice-bowl-kansas-city-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 35,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.1287007927895,
#     'longitude': -94.7711536288261},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '8226 Parallel Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66109',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['8226 Parallel Pkwy', 'Kansas City, KS 66109']},
#    'phone': '+19132998118',
#    'display_phone': '(913) 299-8118',
#    'distance': 5140.998338099374},
#   {'id': 'P06dd4Rh6PmtCKIRjr_AoA',
#    'alias': 'caribe-blue-restaurant-kansas-city-2',
#    'name': 'Caribe Blue Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LXPL6Tm59OHDABEroe-iCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caribe-blue-restaurant-kansas-city-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 5,
#    'categories': [{'alias': 'dominican', 'title': 'Dominican'},
#     {'alias': 'puertorican', 'title': 'Puerto Rican'},
#     {'alias': 'cuban', 'title': 'Cuban'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.110205, 'longitude': -94.621633},
#    'transactions': [],
#    'location': {'address1': '402 North 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66101',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['402 North 5th St', 'Kansas City, KS 66101']},
#    'phone': '+19132329971',
#    'display_phone': '(913) 232-9971',
#    'distance': 9592.020932206346},
#   {'id': 'f7HunWgFex8DVrT34kVI-g',
#    'alias': 'twisted-fresh-shawnee',
#    'name': 'Twisted Fresh',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oOGeDE8zhxy4CdJu1BCi2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twisted-fresh-shawnee?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 184,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.0099378, 'longitude': -94.8408009},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '22030 W 66th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Shawnee',
#     'zip_code': '66226',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['22030 W 66th St', 'Shawnee, KS 66226']},
#    'phone': '+19134410444',
#    'display_phone': '(913) 441-0444',
#    'distance': 13438.560439455494},
#   {'id': 'SBY6iH9UpR6b8Cg6gOrz9Q',
#    'alias': 'mclain-s-market-shawnee-shawnee',
#    'name': 'McLain’s Market - Shawnee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tjUT1mzfEYKBoetMvsqBxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mclain-s-market-shawnee-shawnee?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 24,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.022291, 'longitude': -94.714117},
#    'transactions': [],
#    'location': {'address1': '5833 Nieman Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Shawnee',
#     'zip_code': '66203',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['5833 Nieman Rd', 'Shawnee, KS 66203']},
#    'phone': '+19132159288',
#    'display_phone': '(913) 215-9288',
#    'distance': 8179.7338666727},
#   {'id': 'BVs9Q1mLucmup85_yk5obw',
#    'alias': 'pauls-drive-in-kansas-city-2',
#    'name': "Paul's Drive In",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tPu-O14MB_9_UW5i2AyeFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pauls-drive-in-kansas-city-2?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 36,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.084373, 'longitude': -94.63586},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1008 Osage Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '66105',
#     'country': 'US',
#     'state': 'KS',
#     'display_address': ['1008 Osage Ave', 'Kansas City, KS 66105']},
#    'phone': '+19133718490',
#    'display_phone': '(913) 371-8490',
#    'distance': 8290.155895302141},
#   {'id': 'Q29r313KvqpOhaBiQwYolw',
#    'alias': 'blue-koi-noodles-and-dumplings-kansas-city-3',
#    'name': 'Blue Koi Noodles & Dumplings',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_tbCMyxGN9OIPrIkY7tYqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-koi-noodles-and-dumplings-kansas-city-3?adjust_creative=7UN0GtEVQ3qkw9runiTDpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7UN0GtEVQ3qkw9runiTDpA',
#    'review_count': 547,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.0572802722454,
#     'longitude': -94.6062279492617},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1803 W 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Kansas City',
#     'zip_code': '64111',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['1803 W 39th St', 'Kansas City, MO 64111']},
#    'phone': '+18165615003',
#    'display_phone': '(816) 561-5003',
#    'distance': 11536.252308960326}],
#  'total': 536,
#  'region': {'center': {'longitude': -94.73098754882812,
#    'latitude': 39.09471589907227}}}
